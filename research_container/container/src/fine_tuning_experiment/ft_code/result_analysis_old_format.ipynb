# %% [markdown]
# # Result Analysis

# %%
import json
import pandas as pd

# %% [markdown]
# ## Open Files

# %%
# Open the JSON file

input_data = {}

for i in range(1, 6):
    path = './../ft_results/fold_' + str(i) + '/results_' + str(i) + '.json'

    with open(path) as json_file:
        input_data[f'fold_{i}'] = json.load(json_file)

print(json.dumps(input_data, indent=4))
# Out:
# {
#     "fold_1": {
#         "Experiments": [
#             {
#                 "Results": {
#                     "Accuracy": "97.6190%",
#                     "Precision": "97.4003%",
#                     "Recall": "97.6316%",
#                     "F-1_Score": "97.4117%",
#                     "Best_Epoch": {
#                         "epoch": 31,
#                         "train_loss": "0.0074",
#                         "val_loss": "0.0805",
#                         "train_accuracy": "99.0566%",
#                         "val_accuracy": "91.7411%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "SGD",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.001
#                     }
#                 },
#                 "Fold_Number": 1,
#                 "Experiment_ID": 0
#             },
#             {
#                 "Results": {
#                     "Accuracy": "97.1429%",
#                     "Precision": "96.9877%",
#                     "Recall": "97.4055%",
#                     "F-1_Score": "96.9190%",
#                     "Best_Epoch": {
#                         "epoch": 32,
#                         "train_loss": "0.0083",
#                         "val_loss": "0.0791",
#                         "train_accuracy": "99.0566%",
#                         "val_accuracy": "91.7411%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "SGD",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.001
#                     }
#                 },
#                 "Fold_Number": 1,
#                 "Experiment_ID": 1
#             },
#             {
#                 "Results": {
#                     "Accuracy": "97.6190%",
#                     "Precision": "97.3402%",
#                     "Recall": "97.7946%",
#                     "F-1_Score": "97.4909%",
#                     "Best_Epoch": {
#                         "epoch": 78,
#                         "train_loss": "0.0506",
#                         "val_loss": "0.1225",
#                         "train_accuracy": "98.8797%",
#                         "val_accuracy": "91.9643%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "SGD",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.0001
#                     }
#                 },
#                 "Fold_Number": 1,
#                 "Experiment_ID": 2
#             },
#             {
#                 "Results": {
#                     "Accuracy": "97.8571%",
#                     "Precision": "97.5987%",
#                     "Recall": "97.6190%",
#                     "F-1_Score": "97.4728%",
#                     "Best_Epoch": {
#                         "epoch": 43,
#                         "train_loss": "0.0003",
#                         "val_loss": "0.1023",
#                         "train_accuracy": "99.0566%",
#                         "val_accuracy": "92.4107%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "SGD",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.01
#                     }
#                 },
#                 "Fold_Number": 1,
#                 "Experiment_ID": 3
#             },
#             {
#                 "Results": {
#                     "Accuracy": "65.2381%",
#                     "Precision": "64.2219%",
#                     "Recall": "66.6957%",
#                     "F-1_Score": "63.8133%",
#                     "Best_Epoch": {
#                         "epoch": 59,
#                         "train_loss": "0.0474",
#                         "val_loss": "1.9380",
#                         "train_accuracy": "97.5826%",
#                         "val_accuracy": "64.9554%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "Adam",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.1
#                     }
#                 },
#                 "Fold_Number": 1,
#                 "Experiment_ID": 4
#             },
#             {
#                 "Results": {
#                     "Accuracy": "97.3810%",
#                     "Precision": "96.9986%",
#                     "Recall": "97.3475%",
#                     "F-1_Score": "97.1348%",
#                     "Best_Epoch": {
#                         "epoch": 64,
#                         "train_loss": "0.0012",
#                         "val_loss": "0.0705",
#                         "train_accuracy": "99.0566%",
#                         "val_accuracy": "92.6339%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "AdamW",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.0001
#                     }
#                 },
#                 "Fold_Number": 1,
#                 "Experiment_ID": 5
#             },
#             {
#                 "Results": {
#                     "Accuracy": "94.0476%",
#                     "Precision": "93.6665%",
#                     "Recall": "94.0368%",
#                     "F-1_Score": "93.5548%",
#                     "Best_Epoch": {
#                         "epoch": 60,
#                         "train_loss": "0.0016",
#                         "val_loss": "0.1433",
#                         "train_accuracy": "98.9976%",
#                         "val_accuracy": "90.1786%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "Adam",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.001
#                     }
#                 },
#                 "Fold_Number": 1,
#                 "Experiment_ID": 6
#             },
#             {
#                 "Results": {
#                     "Accuracy": "95.9524%",
#                     "Precision": "95.6325%",
#                     "Recall": "95.9512%",
#                     "F-1_Score": "95.5843%",
#                     "Best_Epoch": {
#                         "epoch": 16,
#                         "train_loss": "0.0127",
#                         "val_loss": "0.0981",
#                         "train_accuracy": "98.7618%",
#                         "val_accuracy": "92.4107%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "Adam",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.0001
#                     }
#                 },
#                 "Fold_Number": 1,
#                 "Experiment_ID": 7
#             },
#             {
#                 "Results": {
#                     "Accuracy": "73.8095%",
#                     "Precision": "72.4907%",
#                     "Recall": "78.1450%",
#                     "F-1_Score": "72.1629%",
#                     "Best_Epoch": {
#                         "epoch": 56,
#                         "train_loss": "0.0065",
#                         "val_loss": "0.7459",
#                         "train_accuracy": "98.9387%",
#                         "val_accuracy": "77.9018%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "Adam",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.01
#                     }
#                 },
#                 "Fold_Number": 1,
#                 "Experiment_ID": 8
#             },
#             {
#                 "Results": {
#                     "Accuracy": "75.7143%",
#                     "Precision": "74.5952%",
#                     "Recall": "75.6975%",
#                     "F-1_Score": "74.1283%",
#                     "Best_Epoch": {
#                         "epoch": 90,
#                         "train_loss": "0.0115",
#                         "val_loss": "1.1285",
#                         "train_accuracy": "98.7618%",
#                         "val_accuracy": "73.8839%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "SGD",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.1
#                     }
#                 },
#                 "Fold_Number": 1,
#                 "Experiment_ID": 9
#             },
#             {
#                 "Results": {
#                     "Accuracy": "81.4286%",
#                     "Precision": "81.0106%",
#                     "Recall": "82.8307%",
#                     "F-1_Score": "81.0128%",
#                     "Best_Epoch": {
#                         "epoch": 97,
#                         "train_loss": "0.0171",
#                         "val_loss": "0.7132",
#                         "train_accuracy": "98.7618%",
#                         "val_accuracy": "78.3482%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "AdamW",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.01
#                     }
#                 },
#                 "Fold_Number": 1,
#                 "Experiment_ID": 10
#             },
#             {
#                 "Results": {
#                     "Accuracy": "57.8571%",
#                     "Precision": "57.4707%",
#                     "Recall": "64.0769%",
#                     "F-1_Score": "56.8450%",
#                     "Best_Epoch": {
#                         "epoch": 57,
#                         "train_loss": "0.4309",
#                         "val_loss": "1.0794",
#                         "train_accuracy": "85.7901%",
#                         "val_accuracy": "67.6339%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "AdamW",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.1
#                     }
#                 },
#                 "Fold_Number": 1,
#                 "Experiment_ID": 11
#             },
#             {
#                 "Results": {
#                     "Accuracy": "92.3810%",
#                     "Precision": "91.9076%",
#                     "Recall": "92.7064%",
#                     "F-1_Score": "91.8048%",
#                     "Best_Epoch": {
#                         "epoch": 36,
#                         "train_loss": "0.0187",
#                         "val_loss": "0.2074",
#                         "train_accuracy": "98.4670%",
#                         "val_accuracy": "89.9554%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "AdamW",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.001
#                     }
#                 },
#                 "Fold_Number": 1,
#                 "Experiment_ID": 12
#             }
#         ]
#     },
#     "fold_2": {
#         "Experiments": [
#             {
#                 "Results": {
#                     "Accuracy": "94.7619%",
#                     "Precision": "94.3052%",
#                     "Recall": "94.9395%",
#                     "F-1_Score": "94.4958%",
#                     "Best_Epoch": {
#                         "epoch": 70,
#                         "train_loss": "0.0026",
#                         "val_loss": "0.1768",
#                         "train_accuracy": "99.0566%",
#                         "val_accuracy": "89.7321%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "AdamW",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.001
#                     }
#                 },
#                 "Fold_Number": 2,
#                 "Experiment_ID": 0
#             },
#             {
#                 "Results": {
#                     "Accuracy": "71.4286%",
#                     "Precision": "70.2762%",
#                     "Recall": "75.7053%",
#                     "F-1_Score": "70.5127%",
#                     "Best_Epoch": {
#                         "epoch": 48,
#                         "train_loss": "0.0117",
#                         "val_loss": "0.9809",
#                         "train_accuracy": "98.8797%",
#                         "val_accuracy": "76.3393%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "Adam",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.01
#                     }
#                 },
#                 "Fold_Number": 2,
#                 "Experiment_ID": 1
#             },
#             {
#                 "Results": {
#                     "Accuracy": "96.1905%",
#                     "Precision": "95.8307%",
#                     "Recall": "96.3083%",
#                     "F-1_Score": "95.9416%",
#                     "Best_Epoch": {
#                         "epoch": 68,
#                         "train_loss": "0.0007",
#                         "val_loss": "0.1364",
#                         "train_accuracy": "99.0566%",
#                         "val_accuracy": "90.4018%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "Adam",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.001
#                     }
#                 },
#                 "Fold_Number": 2,
#                 "Experiment_ID": 2
#             },
#             {
#                 "Results": {
#                     "Accuracy": "98.8095%",
#                     "Precision": "98.7349%",
#                     "Recall": "98.7571%",
#                     "F-1_Score": "98.7061%",
#                     "Best_Epoch": {
#                         "epoch": 22,
#                         "train_loss": "0.0007",
#                         "val_loss": "0.0367",
#                         "train_accuracy": "99.0566%",
#                         "val_accuracy": "92.8571%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "SGD",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.01
#                     }
#                 },
#                 "Fold_Number": 2,
#                 "Experiment_ID": 3
#             }
#         ]
#     },
#     "fold_3": {
#         "Experiments": [
#             {
#                 "Results": {
#                     "Accuracy": "97.3810%",
#                     "Precision": "97.6536%",
#                     "Recall": "97.5824%",
#                     "F-1_Score": "97.5681%",
#                     "Best_Epoch": {
#                         "epoch": 22,
#                         "train_loss": "0.0037",
#                         "val_loss": "0.0627",
#                         "train_accuracy": "99.0566%",
#                         "val_accuracy": "92.1875%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "Adam",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.0001
#                     }
#                 },
#                 "Fold_Number": 3,
#                 "Experiment_ID": 0
#             },
#             {
#                 "Results": {
#                     "Accuracy": "75.9524%",
#                     "Precision": "75.4595%",
#                     "Recall": "77.2489%",
#                     "F-1_Score": "74.9590%",
#                     "Best_Epoch": {
#                         "epoch": 68,
#                         "train_loss": "0.0232",
#                         "val_loss": "0.9210",
#                         "train_accuracy": "98.8797%",
#                         "val_accuracy": "77.9018%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "AdamW",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.01
#                     }
#                 },
#                 "Fold_Number": 3,
#                 "Experiment_ID": 1
#             },
#             {
#                 "Results": {
#                     "Accuracy": "82.3810%",
#                     "Precision": "83.1901%",
#                     "Recall": "83.7815%",
#                     "F-1_Score": "82.0514%",
#                     "Best_Epoch": {
#                         "epoch": 94,
#                         "train_loss": "0.0132",
#                         "val_loss": "0.9063",
#                         "train_accuracy": "98.7618%",
#                         "val_accuracy": "79.2411%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "Adam",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.01
#                     }
#                 },
#                 "Fold_Number": 3,
#                 "Experiment_ID": 2
#             },
#             {
#                 "Results": {
#                     "Accuracy": "81.4286%",
#                     "Precision": "81.3332%",
#                     "Recall": "81.7145%",
#                     "F-1_Score": "80.9543%",
#                     "Best_Epoch": {
#                         "epoch": 88,
#                         "train_loss": "0.0175",
#                         "val_loss": "0.7975",
#                         "train_accuracy": "98.5259%",
#                         "val_accuracy": "77.0089%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "SGD",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.1
#                     }
#                 },
#                 "Fold_Number": 3,
#                 "Experiment_ID": 3
#             }
#         ]
#     },
#     "fold_4": {
#         "Experiments": [
#             {
#                 "Results": {
#                     "Accuracy": "97.1429%",
#                     "Precision": "97.1818%",
#                     "Recall": "97.1826%",
#                     "F-1_Score": "97.1418%",
#                     "Best_Epoch": {
#                         "epoch": 21,
#                         "train_loss": "0.0135",
#                         "val_loss": "0.0859",
#                         "train_accuracy": "99.0566%",
#                         "val_accuracy": "91.5179%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "SGD",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.001
#                     }
#                 },
#                 "Fold_Number": 4,
#                 "Experiment_ID": 0
#             },
#             {
#                 "Results": {
#                     "Accuracy": "75.9524%",
#                     "Precision": "76.2600%",
#                     "Recall": "76.3078%",
#                     "F-1_Score": "75.5720%",
#                     "Best_Epoch": {
#                         "epoch": 90,
#                         "train_loss": "0.0091",
#                         "val_loss": "1.1425",
#                         "train_accuracy": "98.9387%",
#                         "val_accuracy": "74.1071%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "SGD",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.1
#                     }
#                 },
#                 "Fold_Number": 4,
#                 "Experiment_ID": 1
#             },
#             {
#                 "Results": {
#                     "Accuracy": "98.5714%",
#                     "Precision": "98.5672%",
#                     "Recall": "98.5821%",
#                     "F-1_Score": "98.5241%",
#                     "Best_Epoch": {
#                         "epoch": 97,
#                         "train_loss": "0.0002",
#                         "val_loss": "0.0485",
#                         "train_accuracy": "99.0566%",
#                         "val_accuracy": "92.8571%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "SGD",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.01
#                     }
#                 },
#                 "Fold_Number": 4,
#                 "Experiment_ID": 2
#             },
#             {
#                 "Results": {
#                     "Accuracy": "98.8095%",
#                     "Precision": "98.8823%",
#                     "Recall": "99.0474%",
#                     "F-1_Score": "98.9476%",
#                     "Best_Epoch": {
#                         "epoch": 33,
#                         "train_loss": "0.0051",
#                         "val_loss": "0.0547",
#                         "train_accuracy": "98.9387%",
#                         "val_accuracy": "92.6339%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "Adam",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.0001
#                     }
#                 },
#                 "Fold_Number": 4,
#                 "Experiment_ID": 3
#             },
#             {
#                 "Results": {
#                     "Accuracy": "67.3810%",
#                     "Precision": "68.6426%",
#                     "Recall": "68.8843%",
#                     "F-1_Score": "67.5403%",
#                     "Best_Epoch": {
#                         "epoch": 100,
#                         "train_loss": "0.0180",
#                         "val_loss": "2.1217",
#                         "train_accuracy": "98.5849%",
#                         "val_accuracy": "63.1696%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "Adam",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.1
#                     }
#                 },
#                 "Fold_Number": 4,
#                 "Experiment_ID": 4
#             },
#             {
#                 "Results": {
#                     "Accuracy": "97.1429%",
#                     "Precision": "97.3144%",
#                     "Recall": "97.4524%",
#                     "F-1_Score": "97.3501%",
#                     "Best_Epoch": {
#                         "epoch": 100,
#                         "train_loss": "0.0325",
#                         "val_loss": "0.1045",
#                         "train_accuracy": "99.0566%",
#                         "val_accuracy": "91.0714%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "SGD",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.0001
#                     }
#                 },
#                 "Fold_Number": 4,
#                 "Experiment_ID": 5
#             },
#             {
#                 "Results": {
#                     "Accuracy": "97.6190%",
#                     "Precision": "97.5962%",
#                     "Recall": "97.9159%",
#                     "F-1_Score": "97.6836%",
#                     "Best_Epoch": {
#                         "epoch": 20,
#                         "train_loss": "0.0152",
#                         "val_loss": "0.0787",
#                         "train_accuracy": "99.0566%",
#                         "val_accuracy": "91.9643%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "SGD",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.001
#                     }
#                 },
#                 "Fold_Number": 4,
#                 "Experiment_ID": 6
#             },
#             {
#                 "Results": {
#                     "Accuracy": "98.0952%",
#                     "Precision": "98.1291%",
#                     "Recall": "98.4279%",
#                     "F-1_Score": "98.2272%",
#                     "Best_Epoch": {
#                         "epoch": 48,
#                         "train_loss": "0.0005",
#                         "val_loss": "0.0478",
#                         "train_accuracy": "99.0566%",
#                         "val_accuracy": "92.8571%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "AdamW",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.0001
#                     }
#                 },
#                 "Fold_Number": 4,
#                 "Experiment_ID": 7
#             },
#             {
#                 "Results": {
#                     "Accuracy": "91.1905%",
#                     "Precision": "91.2319%",
#                     "Recall": "92.1948%",
#                     "F-1_Score": "91.1273%",
#                     "Best_Epoch": {
#                         "epoch": 52,
#                         "train_loss": "0.0025",
#                         "val_loss": "0.1212",
#                         "train_accuracy": "98.9976%",
#                         "val_accuracy": "91.2946%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "AdamW",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.001
#                     }
#                 },
#                 "Fold_Number": 4,
#                 "Experiment_ID": 8
#             },
#             {
#                 "Results": {
#                     "Accuracy": "82.3810%",
#                     "Precision": "82.8414%",
#                     "Recall": "82.5171%",
#                     "F-1_Score": "82.2747%",
#                     "Best_Epoch": {
#                         "epoch": 60,
#                         "train_loss": "0.0241",
#                         "val_loss": "0.7017",
#                         "train_accuracy": "98.2901%",
#                         "val_accuracy": "78.5714%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "AdamW",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.01
#                     }
#                 },
#                 "Fold_Number": 4,
#                 "Experiment_ID": 9
#             },
#             {
#                 "Results": {
#                     "Accuracy": "92.1429%",
#                     "Precision": "91.6358%",
#                     "Recall": "93.3141%",
#                     "F-1_Score": "91.7864%",
#                     "Best_Epoch": {
#                         "epoch": 30,
#                         "train_loss": "0.0289",
#                         "val_loss": "0.1299",
#                         "train_accuracy": "98.2901%",
#                         "val_accuracy": "90.4018%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "Adam",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.001
#                     }
#                 },
#                 "Fold_Number": 4,
#                 "Experiment_ID": 10
#             },
#             {
#                 "Results": {
#                     "Accuracy": "41.6667%",
#                     "Precision": "41.5687%",
#                     "Recall": "49.3048%",
#                     "F-1_Score": "39.1927%",
#                     "Best_Epoch": {
#                         "epoch": 48,
#                         "train_loss": "0.6187",
#                         "val_loss": "1.6603",
#                         "train_accuracy": "79.3632%",
#                         "val_accuracy": "56.2500%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "AdamW",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.1
#                     }
#                 },
#                 "Fold_Number": 4,
#                 "Experiment_ID": 11
#             },
#             {
#                 "Results": {
#                     "Accuracy": "71.1905%",
#                     "Precision": "71.1137%",
#                     "Recall": "75.7155%",
#                     "F-1_Score": "69.5770%",
#                     "Best_Epoch": {
#                         "epoch": 54,
#                         "train_loss": "0.0189",
#                         "val_loss": "0.6486",
#                         "train_accuracy": "98.3491%",
#                         "val_accuracy": "78.7946%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "Adam",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.01
#                     }
#                 },
#                 "Fold_Number": 4,
#                 "Experiment_ID": 12
#             }
#         ]
#     },
#     "fold_5": {
#         "Experiments": [
#             {
#                 "Results": {
#                     "Accuracy": "97.3810%",
#                     "Precision": "97.6887%",
#                     "Recall": "97.6517%",
#                     "F-1_Score": "97.5606%",
#                     "Best_Epoch": {
#                         "epoch": 87,
#                         "train_loss": "0.0021",
#                         "val_loss": "0.0819",
#                         "train_accuracy": "99.0566%",
#                         "val_accuracy": "91.7411%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "SGD",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.001
#                     }
#                 },
#                 "Fold_Number": 5,
#                 "Experiment_ID": 0
#             },
#             {
#                 "Results": {
#                     "Accuracy": "97.8571%",
#                     "Precision": "97.9197%",
#                     "Recall": "97.7064%",
#                     "F-1_Score": "97.7320%",
#                     "Best_Epoch": {
#                         "epoch": 20,
#                         "train_loss": "0.0006",
#                         "val_loss": "0.0441",
#                         "train_accuracy": "99.0566%",
#                         "val_accuracy": "92.6339%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "SGD",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.01
#                     }
#                 },
#                 "Fold_Number": 5,
#                 "Experiment_ID": 1
#             },
#             {
#                 "Results": {
#                     "Accuracy": "64.5238%",
#                     "Precision": "67.4261%",
#                     "Recall": "67.9933%",
#                     "F-1_Score": "64.8586%",
#                     "Best_Epoch": {
#                         "epoch": 52,
#                         "train_loss": "0.1319",
#                         "val_loss": "1.8853",
#                         "train_accuracy": "95.0472%",
#                         "val_accuracy": "62.2768%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "Adam",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.1
#                     }
#                 },
#                 "Fold_Number": 5,
#                 "Experiment_ID": 2
#             },
#             {
#                 "Results": {
#                     "Accuracy": "75.2381%",
#                     "Precision": "76.8266%",
#                     "Recall": "78.2464%",
#                     "F-1_Score": "76.1790%",
#                     "Best_Epoch": {
#                         "epoch": 44,
#                         "train_loss": "0.0425",
#                         "val_loss": "0.9952",
#                         "train_accuracy": "97.8774%",
#                         "val_accuracy": "73.8839%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "AdamW",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.01
#                     }
#                 },
#                 "Fold_Number": 5,
#                 "Experiment_ID": 3
#             },
#             {
#                 "Results": {
#                     "Accuracy": "89.5238%",
#                     "Precision": "90.4744%",
#                     "Recall": "90.5135%",
#                     "F-1_Score": "90.0780%",
#                     "Best_Epoch": {
#                         "epoch": 55,
#                         "train_loss": "0.0006",
#                         "val_loss": "0.1194",
#                         "train_accuracy": "99.0566%",
#                         "val_accuracy": "90.4018%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "Adam",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.001
#                     }
#                 },
#                 "Fold_Number": 5,
#                 "Experiment_ID": 4
#             },
#             {
#                 "Results": {
#                     "Accuracy": "64.0476%",
#                     "Precision": "66.2000%",
#                     "Recall": "69.8829%",
#                     "F-1_Score": "65.2038%",
#                     "Best_Epoch": {
#                         "epoch": 91,
#                         "train_loss": "0.3164",
#                         "val_loss": "1.5538",
#                         "train_accuracy": "88.6792%",
#                         "val_accuracy": "62.5000%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "AdamW",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.1
#                     }
#                 },
#                 "Fold_Number": 5,
#                 "Experiment_ID": 5
#             },
#             {
#                 "Results": {
#                     "Accuracy": "90.7143%",
#                     "Precision": "91.0950%",
#                     "Recall": "90.6676%",
#                     "F-1_Score": "90.6031%",
#                     "Best_Epoch": {
#                         "epoch": 21,
#                         "train_loss": "0.0032",
#                         "val_loss": "0.1333",
#                         "train_accuracy": "99.0566%",
#                         "val_accuracy": "90.8482%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "AdamW",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.001
#                     }
#                 },
#                 "Fold_Number": 5,
#                 "Experiment_ID": 6
#             },
#             {
#                 "Results": {
#                     "Accuracy": "97.6190%",
#                     "Precision": "97.9112%",
#                     "Recall": "97.8432%",
#                     "F-1_Score": "97.8285%",
#                     "Best_Epoch": {
#                         "epoch": 57,
#                         "train_loss": "0.0893",
#                         "val_loss": "0.1746",
#                         "train_accuracy": "98.7028%",
#                         "val_accuracy": "91.7411%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "SGD",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.0001
#                     }
#                 },
#                 "Fold_Number": 5,
#                 "Experiment_ID": 7
#             },
#             {
#                 "Results": {
#                     "Accuracy": "95.9524%",
#                     "Precision": "96.2544%",
#                     "Recall": "96.2764%",
#                     "F-1_Score": "96.1213%",
#                     "Best_Epoch": {
#                         "epoch": 13,
#                         "train_loss": "0.0046",
#                         "val_loss": "0.0525",
#                         "train_accuracy": "98.9976%",
#                         "val_accuracy": "92.8571%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "Adam",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.0001
#                     }
#                 },
#                 "Fold_Number": 5,
#                 "Experiment_ID": 8
#             },
#             {
#                 "Results": {
#                     "Accuracy": "98.0952%",
#                     "Precision": "98.2812%",
#                     "Recall": "98.2556%",
#                     "F-1_Score": "98.1743%",
#                     "Best_Epoch": {
#                         "epoch": 29,
#                         "train_loss": "0.0088",
#                         "val_loss": "0.0845",
#                         "train_accuracy": "99.0566%",
#                         "val_accuracy": "91.9643%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "SGD",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.001
#                     }
#                 },
#                 "Fold_Number": 5,
#                 "Experiment_ID": 9
#             },
#             {
#                 "Results": {
#                     "Accuracy": "77.3810%",
#                     "Precision": "79.2897%",
#                     "Recall": "80.1421%",
#                     "F-1_Score": "78.1330%",
#                     "Best_Epoch": {
#                         "epoch": 56,
#                         "train_loss": "0.0096",
#                         "val_loss": "0.9469",
#                         "train_accuracy": "98.9387%",
#                         "val_accuracy": "75.2232%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "SGD",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.1
#                     }
#                 },
#                 "Fold_Number": 5,
#                 "Experiment_ID": 10
#             },
#             {
#                 "Results": {
#                     "Accuracy": "79.7619%",
#                     "Precision": "80.9986%",
#                     "Recall": "81.2154%",
#                     "F-1_Score": "80.3413%",
#                     "Best_Epoch": {
#                         "epoch": 83,
#                         "train_loss": "0.0039",
#                         "val_loss": "0.9004",
#                         "train_accuracy": "98.9387%",
#                         "val_accuracy": "77.2321%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "Adam",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.01
#                     }
#                 },
#                 "Fold_Number": 5,
#                 "Experiment_ID": 11
#             },
#             {
#                 "Results": {
#                     "Accuracy": "97.1429%",
#                     "Precision": "97.4302%",
#                     "Recall": "97.2627%",
#                     "F-1_Score": "97.2381%",
#                     "Best_Epoch": {
#                         "epoch": 8,
#                         "train_loss": "0.0085",
#                         "val_loss": "0.0853",
#                         "train_accuracy": "99.0566%",
#                         "val_accuracy": "92.4107%"
#                     },
#                     "Hyper_Parameters": {
#                         "Epochs": 100,
#                         "Optimizer": "AdamW",
#                         "Loss_Function": "CrossEntropy",
#                         "Batch_Size": 32,
#                         "Learning_Rate": 0.0001
#                     }
#                 },
#                 "Fold_Number": 5,
#                 "Experiment_ID": 12
#             }
#         ]
#     }
# }

# %% [markdown]
# ### Data Format
# ```python
# data {
#   optimizer {
#     learning_rate {
#       results = Dataframe[Accuracy, Precision, Recall, F1][5]
#       cum_results = Dataframe[Accuracy, Precision, Recall, F1]
#     }
#   }
# }
# ```

# %%
learning_rates = [0.1, 0.01, 0.001, 0.0001]
optimizers = ["SGD", "Adam", "AdamW"]

data = {}
for optimizer in optimizers:
    data[optimizer] = {}
    for learning_rate in learning_rates:
        data[optimizer][learning_rate] = {
            "results": pd.DataFrame(columns=['Accuracy', 'Precision', 'Recall', 'F-1_Score'], index=range(5)),
            "cum_results": pd.DataFrame(columns=['Accuracy', 'Precision', 'Recall', 'F-1_Score'])
        }
# print(json.dumps(data, indent=4))

data
# Out:
# {'SGD': {0.1: {'results':   Accuracy Precision Recall F-1_Score
#    0      NaN       NaN    NaN       NaN
#    1      NaN       NaN    NaN       NaN
#    2      NaN       NaN    NaN       NaN
#    3      NaN       NaN    NaN       NaN
#    4      NaN       NaN    NaN       NaN,
#    'cum_results': Empty DataFrame
#    Columns: [Accuracy, Precision, Recall, F-1_Score]
#    Index: []},
#   0.01: {'results':   Accuracy Precision Recall F-1_Score
#    0      NaN       NaN    NaN       NaN
#    1      NaN       NaN    NaN       NaN
#    2      NaN       NaN    NaN       NaN
#    3      NaN       NaN    NaN       NaN
#    4      NaN       NaN    NaN       NaN,
#    'cum_results': Empty DataFrame
#    Columns: [Accuracy, Precision, Recall, F-1_Score]
#    Index: []},
#   0.001: {'results':   Accuracy Precision Recall F-1_Score
#    0      NaN       NaN    NaN       NaN
#    1      NaN       NaN    NaN       NaN
#    2      NaN       NaN    NaN       NaN
#    3      NaN       NaN    NaN       NaN
#    4      NaN       NaN    NaN       NaN,
#    'cum_results': Empty DataFrame
#    Columns: [Accuracy, Precision, Recall, F-1_Score]
#    Index: []},
#   0.0001: {'results':   Accuracy Precision Recall F-1_Score
#    0      NaN       NaN    NaN       NaN
#    1      NaN       NaN    NaN       NaN
#    2      NaN       NaN    NaN       NaN
#    3      NaN       NaN    NaN       NaN
#    4      NaN       NaN    NaN       NaN,
#    'cum_results': Empty DataFrame
#    Columns: [Accuracy, Precision, Recall, F-1_Score]
#    Index: []}},
#  'Adam': {0.1: {'results':   Accuracy Precision Recall F-1_Score
#    0      NaN       NaN    NaN       NaN
#    1      NaN       NaN    NaN       NaN
#    2      NaN       NaN    NaN       NaN
#    3      NaN       NaN    NaN       NaN
#    4      NaN       NaN    NaN       NaN,
#    'cum_results': Empty DataFrame
#    Columns: [Accuracy, Precision, Recall, F-1_Score]
#    Index: []},
#   0.01: {'results':   Accuracy Precision Recall F-1_Score
#    0      NaN       NaN    NaN       NaN
#    1      NaN       NaN    NaN       NaN
#    2      NaN       NaN    NaN       NaN
#    3      NaN       NaN    NaN       NaN
#    4      NaN       NaN    NaN       NaN,
#    'cum_results': Empty DataFrame
#    Columns: [Accuracy, Precision, Recall, F-1_Score]
#    Index: []},
#   0.001: {'results':   Accuracy Precision Recall F-1_Score
#    0      NaN       NaN    NaN       NaN
#    1      NaN       NaN    NaN       NaN
#    2      NaN       NaN    NaN       NaN
#    3      NaN       NaN    NaN       NaN
#    4      NaN       NaN    NaN       NaN,
#    'cum_results': Empty DataFrame
#    Columns: [Accuracy, Precision, Recall, F-1_Score]
#    Index: []},
#   0.0001: {'results':   Accuracy Precision Recall F-1_Score
#    0      NaN       NaN    NaN       NaN
#    1      NaN       NaN    NaN       NaN
#    2      NaN       NaN    NaN       NaN
#    3      NaN       NaN    NaN       NaN
#    4      NaN       NaN    NaN       NaN,
#    'cum_results': Empty DataFrame
#    Columns: [Accuracy, Precision, Recall, F-1_Score]
#    Index: []}},
#  'AdamW': {0.1: {'results':   Accuracy Precision Recall F-1_Score
#    0      NaN       NaN    NaN       NaN
#    1      NaN       NaN    NaN       NaN
#    2      NaN       NaN    NaN       NaN
#    3      NaN       NaN    NaN       NaN
#    4      NaN       NaN    NaN       NaN,
#    'cum_results': Empty DataFrame
#    Columns: [Accuracy, Precision, Recall, F-1_Score]
#    Index: []},
#   0.01: {'results':   Accuracy Precision Recall F-1_Score
#    0      NaN       NaN    NaN       NaN
#    1      NaN       NaN    NaN       NaN
#    2      NaN       NaN    NaN       NaN
#    3      NaN       NaN    NaN       NaN
#    4      NaN       NaN    NaN       NaN,
#    'cum_results': Empty DataFrame
#    Columns: [Accuracy, Precision, Recall, F-1_Score]
#    Index: []},
#   0.001: {'results':   Accuracy Precision Recall F-1_Score
#    0      NaN       NaN    NaN       NaN
#    1      NaN       NaN    NaN       NaN
#    2      NaN       NaN    NaN       NaN
#    3      NaN       NaN    NaN       NaN
#    4      NaN       NaN    NaN       NaN,
#    'cum_results': Empty DataFrame
#    Columns: [Accuracy, Precision, Recall, F-1_Score]
#    Index: []},
#   0.0001: {'results':   Accuracy Precision Recall F-1_Score
#    0      NaN       NaN    NaN       NaN
#    1      NaN       NaN    NaN       NaN
#    2      NaN       NaN    NaN       NaN
#    3      NaN       NaN    NaN       NaN
#    4      NaN       NaN    NaN       NaN,
#    'cum_results': Empty DataFrame
#    Columns: [Accuracy, Precision, Recall, F-1_Score]
#    Index: []}}}

# %%
metrics = ['Accuracy', 'Precision', 'Recall', 'F-1_Score']

for i in range(1, 6):
    for j, exp in enumerate(input_data[f'fold_{i}']['Experiments']):
        lr = exp['Results']['Hyper_Parameters']['Learning_Rate']
        optim = exp['Results']['Hyper_Parameters']['Optimizer']

        for metric in metrics:
            res = float(exp['Results'][metric].replace("%", ""))


            data[optim][lr]['results'].loc[i, metric]  = res
    

data
# Out:
# {'SGD': {0.1: {'results':   Accuracy Precision   Recall F-1_Score
#    0      NaN       NaN      NaN       NaN
#    1  75.7143   74.5952  75.6975   74.1283
#    2      NaN       NaN      NaN       NaN
#    3  81.4286   81.3332  81.7145   80.9543
#    4  75.9524     76.26  76.3078    75.572
#    5   77.381   79.2897  80.1421    78.133,
#    'cum_results': Empty DataFrame
#    Columns: [Accuracy, Precision, Recall, F-1_Score]
#    Index: []},
#   0.01: {'results':   Accuracy Precision   Recall F-1_Score
#    0      NaN       NaN      NaN       NaN
#    1  97.8571   97.5987   97.619   97.4728
#    2  98.8095   98.7349  98.7571   98.7061
#    3      NaN       NaN      NaN       NaN
#    4  98.5714   98.5672  98.5821   98.5241
#    5  97.8571   97.9197  97.7064    97.732,
#    'cum_results': Empty DataFrame
#    Columns: [Accuracy, Precision, Recall, F-1_Score]
#    Index: []},
#   0.001: {'results':   Accuracy Precision   Recall F-1_Score
#    0      NaN       NaN      NaN       NaN
#    1  97.1429   96.9877  97.4055    96.919
#    2      NaN       NaN      NaN       NaN
#    3      NaN       NaN      NaN       NaN
#    4   97.619   97.5962  97.9159   97.6836
#    5  98.0952   98.2812  98.2556   98.1743,
#    'cum_results': Empty DataFrame
#    Columns: [Accuracy, Precision, Recall, F-1_Score]
#    Index: []},
#   0.0001: {'results':   Accuracy Precision   Recall F-1_Score
#    0      NaN       NaN      NaN       NaN
#    1   97.619   97.3402  97.7946   97.4909
#    2      NaN       NaN      NaN       NaN
#    3      NaN       NaN      NaN       NaN
#    4  97.1429   97.3144  97.4524   97.3501
#    5   97.619   97.9112  97.8432   97.8285,
#    'cum_results': Empty DataFrame
#    Columns: [Accuracy, Precision, Recall, F-1_Score]
#    Index: []}},
#  'Adam': {0.1: {'results':   Accuracy Precision   Recall F-1_Score
#    0      NaN       NaN      NaN       NaN
#    1  65.2381   64.2219  66.6957   63.8133
#    2      NaN       NaN      NaN       NaN
#    3      NaN       NaN      NaN       NaN
#    4   67.381   68.6426  68.8843   67.5403
#    5  64.5238   67.4261  67.9933   64.8586,
#    'cum_results': Empty DataFrame
#    Columns: [Accuracy, Precision, Recall, F-1_Score]
#    Index: []},
#   0.01: {'results':   Accuracy Precision   Recall F-1_Score
#    0      NaN       NaN      NaN       NaN
#    1  73.8095   72.4907   78.145   72.1629
#    2  71.4286   70.2762  75.7053   70.5127
#    3   82.381   83.1901  83.7815   82.0514
#    4  71.1905   71.1137  75.7155    69.577
#    5  79.7619   80.9986  81.2154   80.3413,
#    'cum_results': Empty DataFrame
#    Columns: [Accuracy, Precision, Recall, F-1_Score]
#    Index: []},
#   0.001: {'results':   Accuracy Precision   Recall F-1_Score
#    0      NaN       NaN      NaN       NaN
#    1  94.0476   93.6665  94.0368   93.5548
#    2  96.1905   95.8307  96.3083   95.9416
#    3      NaN       NaN      NaN       NaN
#    4  92.1429   91.6358  93.3141   91.7864
#    5  89.5238   90.4744  90.5135    90.078,
#    'cum_results': Empty DataFrame
#    Columns: [Accuracy, Precision, Recall, F-1_Score]
#    Index: []},
#   0.0001: {'results':   Accuracy Precision   Recall F-1_Score
#    0      NaN       NaN      NaN       NaN
#    1  95.9524   95.6325  95.9512   95.5843
#    2      NaN       NaN      NaN       NaN
#    3   97.381   97.6536  97.5824   97.5681
#    4  98.8095   98.8823  99.0474   98.9476
#    5  95.9524   96.2544  96.2764   96.1213,
#    'cum_results': Empty DataFrame
#    Columns: [Accuracy, Precision, Recall, F-1_Score]
#    Index: []}},
#  'AdamW': {0.1: {'results':   Accuracy Precision   Recall F-1_Score
#    0      NaN       NaN      NaN       NaN
#    1  57.8571   57.4707  64.0769    56.845
#    2      NaN       NaN      NaN       NaN
#    3      NaN       NaN      NaN       NaN
#    4  41.6667   41.5687  49.3048   39.1927
#    5  64.0476      66.2  69.8829   65.2038,
#    'cum_results': Empty DataFrame
#    Columns: [Accuracy, Precision, Recall, F-1_Score]
#    Index: []},
#   0.01: {'results':   Accuracy Precision   Recall F-1_Score
#    0      NaN       NaN      NaN       NaN
#    1  81.4286   81.0106  82.8307   81.0128
#    2      NaN       NaN      NaN       NaN
#    3  75.9524   75.4595  77.2489    74.959
#    4   82.381   82.8414  82.5171   82.2747
#    5  75.2381   76.8266  78.2464    76.179,
#    'cum_results': Empty DataFrame
#    Columns: [Accuracy, Precision, Recall, F-1_Score]
#    Index: []},
#   0.001: {'results':   Accuracy Precision   Recall F-1_Score
#    0      NaN       NaN      NaN       NaN
#    1   92.381   91.9076  92.7064   91.8048
#    2  94.7619   94.3052  94.9395   94.4958
#    3      NaN       NaN      NaN       NaN
#    4  91.1905   91.2319  92.1948   91.1273
#    5  90.7143    91.095  90.6676   90.6031,
#    'cum_results': Empty DataFrame
#    Columns: [Accuracy, Precision, Recall, F-1_Score]
#    Index: []},
#   0.0001: {'results':   Accuracy Precision   Recall F-1_Score
#    0      NaN       NaN      NaN       NaN
#    1   97.381   96.9986  97.3475   97.1348
#    2      NaN       NaN      NaN       NaN
#    3      NaN       NaN      NaN       NaN
#    4  98.0952   98.1291  98.4279   98.2272
#    5  97.1429   97.4302  97.2627   97.2381,
#    'cum_results': Empty DataFrame
#    Columns: [Accuracy, Precision, Recall, F-1_Score]
#    Index: []}}}
